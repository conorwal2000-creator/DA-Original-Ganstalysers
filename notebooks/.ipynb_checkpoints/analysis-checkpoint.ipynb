# %%
# Import required libraries for data quality analysis

import pandas as pd      # For data frame manipulation and CSV reading
import numpy as np       # For numerical computations
import matplotlib.pyplot as plt  # For creating visualizations

# Display plots inline in the notebook
# %matplotlib inline

# Additional plotting utilities
from matplotlib.backends.backend_pdf import PdfPages  # For saving multiple plots to PDF

# %%
try:
    # Reading from a csv file, into a data frame
    df = pd.read_csv('../data/ppr-group-25200353-train.csv',
                    keep_default_na=True,
                    delimiter=',',
                    skipinitialspace=True)
    
    print(f"Successfully loaded dataset with {df.shape[0]} rows and {df.shape[1]} columns:")

    display(df.head(2))
    display(df.tail(2))
    
except FileNotFoundError:
    print("ERROR: The file '../data/ppr-group-25200353-train.csv' was not found.")
except Exception as e:
    print(f"ERROR: An unexpected error occurred: {e}")
# Out:
# Successfully loaded dataset with 54000 rows and 9 columns:
#   Date of Sale (dd/mm/yyyy)                              Address  County  \
# 0                29/02/2016    APT 14, RUSSELL COURT, FELTRIM RD  Dublin
# 1                08/07/2016  19 PARK VILLAS, DEMESNE RD, DUNDALK   Louth
#
#   Eircode    Price (€) Not Full Market Price VAT Exclusive  \
# 0     NaN  €118,487.00                    No            No
# 1     NaN  €222,000.00                    No            No
#
#                  Description of Property Property Size Description
# 0  Second-Hand Dwelling house /Apartment                       NaN
# 1  Second-Hand Dwelling house /Apartment                       NaN
#       Date of Sale (dd/mm/yyyy)                                  Address  \
# 53998                22/01/2024  164 CLUAIN LARACH, KNOCKENDUFF, TRAMORE
# 53999                31/05/2024        THE WILLOWS, FISHERSTOWN, CAMPILE
#
#           County  Eircode    Price (€) Not Full Market Price VAT Exclusive  \
# ...

# %%
# What are the dimensions of the dataset? 
# Check how many rows and columns this dataframe has
print(f"Dataset shape: {df.shape}")
print(f"Number of rows (instances): {df.shape[0]}")
print(f"Number of columns (features): {df.shape[1]}")
print()

# Complete information about the dataframe including non-null counts and memory usage
df.info()
# Out:
# Dataset shape: (54000, 9)
# Number of rows (instances): 54000
# Number of columns (features): 9
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54000 entries, 0 to 53999
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date of Sale (dd/mm/yyyy)  54000 non-null  object
#  1   Address                    54000 non-null  object
#  2   County                     54000 non-null  object
#  3   Eircode                    16897 non-null  object
#  4   Price (€)                  54000 non-null  object
#  5   Not Full Market Price      54000 non-null  object
#  6   VAT Exclusive              54000 non-null  object
#  7   Description of Property    54000 non-null  object
#  8   Property Size Description  2799 non-null   object
# dtypes: object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Correcting Feature Data Types

# %%
# Fixing Price

try:
    # remove euro symbol
    df['Price (€)'] = df['Price (€)'].str.replace('€', '', regex=False)
    
    # remove commas
    df['Price (€)'] = df['Price (€)'].str.replace(',', '', regex=False)
    
    # convert string to float (numeric)
    df['Price (€)'] = pd.to_numeric(df['Price (€)'])
    print("Feature 'Price (€)' corrected to numeric type.")
except AttributeError:
    print("'Price (€)' is correctly formatted.")

# Extracting Date 

# Convert the Time column to datetime format
df['Date of Sale (dd/mm/yyyy)'] = pd.to_datetime(df['Date of Sale (dd/mm/yyyy)'], dayfirst=True)

# Converting to Categorical 

df['County'] = df['County'].astype('category')
df['Not Full Market Price'] = df['Not Full Market Price'].astype('category')
df['VAT Exclusive'] = df['VAT Exclusive'].astype('category')
df['Description of Property'] = df['Description of Property'].astype('category')
df['Property Size Description'] = df['Property Size Description'].astype('category')
df['Eircode'] = df['Eircode'].astype('category') 

print("Updated features to be categorical.")
# Out:
# Feature 'Price (€)' corrected to numeric type.
# Updated features to be categorical.

# %%
print("Dataset Validation Checks:")
print("=" * 60)

# ---------------------------------------------------
# Check 1: Dataset is not empty
# ---------------------------------------------------
if df.empty:
    print("Dataset is empty!")
else:
    print(f"Dataset contains {df.shape[0]:,} rows and {df.shape[1]} columns")


# ---------------------------------------------------
# Check 2: Duplicate Rows
# ---------------------------------------------------
duplicate_rows = df[df.duplicated(keep=False)]

if not duplicate_rows.empty:
    print(f"\nFound {duplicate_rows.shape[0]} duplicate rows:")
    display(duplicate_rows)
else:
    print("\nNo duplicate rows found")


# ---------------------------------------------------
# Check 3: Duplicate Columns (same column values)
# ---------------------------------------------------
duplicate_columns = []
columns = df.columns

for i in range(len(columns)):
    for j in range(i + 1, len(columns)):
        if df[columns[i]].equals(df[columns[j]]):
            duplicate_columns.append((columns[i], columns[j]))

if duplicate_columns:
    print("\nFound duplicate columns (identical values):")
    for col_pair in duplicate_columns:
        print(f"  - {col_pair[0]} and {col_pair[1]}")
else:
    print("\nNo duplicate columns found")


# ---------------------------------------------------
# Check 4: Constant Columns (only one unique value)
# ---------------------------------------------------
constant_columns = [col for col in df.columns if df[col].nunique(dropna=False) == 1]

if constant_columns:
    print("\nFound constant columns:")
    for col in constant_columns:
        unique_value = df[col].iloc[0]
        print(f"  - {col} (constant value: {unique_value})")
else:
    print("\nNo constant columns found")


# ---------------------------------------------------
# Check 5: Unnamed Columns
# ---------------------------------------------------
unnamed_cols = [col for col in df.columns if 'Unnamed' in str(col)]

if unnamed_cols:
    print(f"\nFound unnamed columns: {unnamed_cols}")
else:
    print("\nAll columns have proper names")
# Out:
# Dataset Validation Checks:
# ...
# Dataset contains 54,000 rows and 9 columns
#
# Found 16 duplicate rows:
#       Date of Sale (dd/mm/yyyy)  \
# 4900                 2016-09-26
# 5117                 2016-09-26
# 10761                2017-08-25
# 11787                2017-08-25
# 20324                2019-02-14
# 20346                2019-02-14
# 27623                2020-09-30
# 28975                2020-09-30
# 32189                2021-05-03
# 32469                2021-05-03
# 41530                2022-02-21
# 41707                2022-02-21
# 44508                2023-09-01
# 44731                2023-09-01
# 46026                2023-04-26
# 46515                2023-04-26
#
#                                                  Address     County  Eircode  \
# 4900                 APT 1, 1 MONTENOTTE VIEW, ALBERT RD       Cork      NaN
# 5117                 APT 1, 1 MONTENOTTE VIEW, ALBERT RD       Cork      NaN
# ...

# %%
# Remove 8 duplicate rows - exact same info

before = len(df)
df = df.drop_duplicates().reset_index(drop=True) # to correct indices
after = len(df)

print(f"Removed {before - after} duplicate rows")
# Out:
# Removed 8 duplicate rows

# %%
# After removing duplicate rows, check the amount of address duplicates
duplicate_count = df['Address'].duplicated().sum()
print(f"\nNumber of duplicate addresses: {duplicate_count}")
# Out:
# Number of duplicate addresses: 699

# %%
# Save cleaned data frame to a new CSV file
df.to_csv('../data/ppr-group-25200353-train-cleaned.csv')

# %% [markdown]
# Now that we have our cleaned df and CSV, we can build our DQR tables, prepare plots, and discuss initial findings from the tables and plots.

# %%
def build_numeric_dqr(df, columns, csv_filename=None):
    """
    Builds Data Quality Report Table for numeric features with:
    - Feature
    - Count
    - Missing%
    - Etc.

    Takes parameters: pandas dataframe from cell 2 above, columns from given data...
    """
    results = []

    total_count = len(df)

    for col in columns:
        series = df[col]

        count = total_count
        missing_pct = 100 * series.isna().sum() / total_count
        cardinality = series.nunique(dropna=True)

        min_val = series.min()
        q1 = series.quantile(0.25)
        mean = series.mean()
        median = series.median()
        q3 = series.quantile(0.75)
        max_val = series.max()
        std = series.std()

        results.append([
            col, count, missing_pct, cardinality,
            min_val, q1, mean, median, q3, max_val, std
        ])

    dqr_table = pd.DataFrame(results, columns=[
        "Feature",
        "Count",
        "Missing %",
        "Cardinality",
        "Minimum",
        "1st Quartile",
        "Mean",
        "Median",
        "3rd Quartile",
        "Maximum",
        "Standard Dev."
    ])

    if csv_filename is not None:
        dqr_table.to_csv(csv_filename, index=False)
        
    return dqr_table

# %%
def build_categorical_dqr(df, columns, csv_filename=None):
    """
    Build Data Quality Report table for categorical features.
    """

    results = []

    total_count = len(df)

    for col in columns:
        series = df[col]

        count = total_count
        missing_pct = 100 * series.isna().sum() / total_count
        cardinality = series.nunique(dropna=True)

        value_counts = series.value_counts(dropna=True)

        if len(value_counts) > 0:
            mode = value_counts.index[0]
            mode_freq = value_counts.iloc[0]
            mode_pct = 100 * mode_freq / total_count
        else:
            mode = np.nan
            mode_freq = 0
            mode_pct = 0

        if len(value_counts) > 1:
            second_mode = value_counts.index[1]
            second_mode_freq = value_counts.iloc[1]
            second_mode_pct = 100 * second_mode_freq / total_count
        else:
            second_mode = np.nan
            second_mode_freq = 0
            second_mode_pct = 0

        results.append([
            col, count, missing_pct, cardinality,
            mode, mode_freq, mode_pct,
            second_mode, second_mode_freq, second_mode_pct
        ])

    dqr_table = pd.DataFrame(results, columns=[
        "Feature",
        "Count",
        "Missing %",
        "Cardinality",
        "Mode",
        "Mode Freq.",
        "Mode %",
        "2nd Mode",
        "2nd Mode Freq.",
        "2nd Mode %"
    ])

    if csv_filename is not None:
        dqr_table.to_csv(csv_filename, index=False)
        
    return dqr_table

# %%
# Separate numeric features.
numeric_columns = df.select_dtypes(['int64', 'float64']).columns

# %%
# Separate categorical features.
category_columns = df.select_dtypes(['category']).columns

# %%
# Create Data Quality Report tables
df_numeric_dqr = build_numeric_dqr(df, numeric_columns)
display(df_numeric_dqr)

df_categorical_dqr = build_categorical_dqr(df, category_columns)
display(df_categorical_dqr)
# Out:
#      Feature  Count  Missing %  Cardinality  Minimum  1st Quartile  \
# 0  Price (€)  53992        0.0         6788   5260.0     158590.33
#
#            Mean    Median  3rd Quartile       Maximum  Standard Dev.
# 0  327045.85816  252000.0      365000.0  1.358598e+08   1.108129e+06
#                      Feature  Count  Missing %  Cardinality  \
# 0                     County  53992   0.000000           26
# 1                    Eircode  53992  68.712031        16840
# 2      Not Full Market Price  53992   0.000000            2
# 3              VAT Exclusive  53992   0.000000            2
# 4    Description of Property  53992   0.000000            3
# 5  Property Size Description  53992  94.815899            4
#
#                                                 Mode  Mode Freq.     Mode %  \
# 0                                             Dublin       16573  30.695288
# 1                                            D08X5T9           3   0.005556
# ...

# %% [markdown]
# ## Visualising Numerical Features: Histogram/Boxplots

# %%
# Create subplots for histogram and boxplot
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
df['Price (€)'].hist(ax=axes[0])
axes[0].set_title('Histogram: Price')
axes[0].set_xlabel('Price (€)')
axes[0].set_ylabel('Frequency')

# Boxplot
df['Price (€)'].plot(kind='box', ax=axes[1])
axes[1].set_title('Boxplot: Price (€)')
axes[1].set_ylabel('Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# As can be seen in the histogram above, the price feature is heavily right-skewed. As a result, the below graph shows up to the 99th percentile.

# %%
upper_limit = df['Price (€)'].quantile(0.99)

filtered_prices = df[df['Price (€)'] <= upper_limit]['Price (€)']

plt.figure(figsize=(7,5))
plt.hist(filtered_prices, bins=50)
plt.title('Histogram: Price (Top 1% Removed for Visualization)')
plt.xlabel('Price (€)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Visualizing Categorical Features
#
# **Bar plots** show the frequency distribution of categorical variables. Look for:
# - Imbalanced categories (one category dominates)
# - Rare categories (categories with very few examples)
# - Missing values (shown if `dropna=False`)
#
# These insights help us decide whether to combine categories, remove rare ones, or impute missing values.

# %%
plt.figure(figsize=(10, 6))
ax = df['County'].value_counts(dropna=False).plot(kind='bar', color='steelblue')
plt.title('Distribution of County', fontsize=14, fontweight='bold')
plt.xlabel('County', fontsize=12)
plt.ylabel('Frequency (Count)', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)

# Add value labels on top of bars
for container in ax.containers:
    ax.bar_label(container, fmt='%d')

plt.tight_layout()
plt.show()

# %%
# Bar charts for all categorical features
# dropna=False keeps missing values visible

for col in category_columns:
    if col != 'Eircode':
        plt.figure(figsize=(5,5))
        df[col].value_counts(dropna=False).plot(kind='bar', title=col)
        plt.show()

# df['Eircode_Routing'] = df['Eircode'].str[:3] # this must be changed if we edit eircode to be only first 3 chars above
# plt.figure(figsize=(8,4))

# df['Eircode_Routing'] \
#     .value_counts() \
#     .head(35) \
#     .plot(kind='bar')

# plt.title("Eircode Routing Key – Top 35")
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
# We should discuss this in DQR

df.nlargest(10, 'Price (€)')
# Out:
#       Date of Sale (dd/mm/yyyy)  \
# 38185                2022-12-07
# 27051                2020-02-27
# 36756                2022-04-08
# 53730                2024-06-27
# 14692                2018-04-27
# 36710                2022-09-06
# 38864                2022-05-17
# 41726                2022-12-08
# 37737                2022-06-13
# 29686                2020-02-17
#
#                                                  Address   County  Eircode  \
# 38185    Apartment Development, at Castleview, Carriglea   Dublin      NaN
# 27051   189 APARTMENTS AT ELMFIELD, BALLYOGAN, DUBLIN 18   Dublin      NaN
# 36756  Student Accommodation Building, 35-38 Cork Street   Dublin      NaN
# 53730  Blocks 5A-5D (including basement), Belmayne Av...   Dublin      NaN
# 14692               1 THE ELYSIAN, EGLINTON STREET, CORK     Cork      NaN
# 36710       1 HAMPTON WOOD SQUARE, HAMPTON WOOD, FINGLAS   Dublin  D11F40H
# 38864  Avalon House  55 Aungier, Street  Dublin 2 and...   Dublin  D08XYE6
# ...

# %% [markdown]
# ## Other visualisations

# %%
# df['Eircode_Routing'] = df['Eircode'].str[:3]
# plt.figure(figsize=(8,4))

# df['Eircode_Routing'] \
#     .value_counts() \
#     .head(35) \
#     .plot(kind='bar')

# plt.title("Eircode Routing Key – Top 35")
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
# Can be removed, just wanted to see if it would be useful

df['Address'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Most Frequent Addresses")
plt.ylabel("Number of Transactions")
plt.xticks(rotation=45)
plt.show()

# %%
import missingno as msno
msno.matrix(df)

plt.title("Missing Data Pattern")
plt.show()

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Data Quality Plan
#
# Solutions to above problems. Final decision on feature types. No more NaN features. Must list every feature, its data type and issues identified plus solutions.

# %%
# Price Data Handling Strategies

# visualising outlier data and performing clamping
import seaborn as sns

sns.boxplot(x=df["Price (€)"])
plt.title("Boxplot for Outlier Detection")
plt.show()

Q1 = df["Price (€)"].quantile(0.25)
Q3 = df["Price (€)"].quantile(0.75)

# testing IQR clamping method outlined in textbook
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Below lower bound (IQR):")
print(df.loc[df["Price (€)"] < lower_bound, "Price (€)"])

print("\nLowest 5 values above upper bound (IQR):")
print(df.loc[df["Price (€)"] > upper_bound, "Price (€)"].sort_values().head(5))
print()
# this won't work as well for our data

# now trying using percentiles

# visualise potential top percentiles
print("percentilessssss")
print(df["Price (€)"].describe(percentiles=[0.9,0.95,0.99,0.995]).apply(lambda x: f"{x:,.2f}"))


lower = df["Price (€)"].quantile(0.01)
upper = df["Price (€)"].quantile(0.99)

print("1st percentile:", lower)
print("99th percentile:", upper)

# perform 99th percentile clamping
df["Price (€)"] = df["Price (€)"].clip(upper=upper)

# confirm that clamping worked
df["Price (€)"].nlargest(5)
# Out:
# Below lower bound (IQR):
# Series([], Name: Price (€), dtype: float64)
#
# Lowest 5 values above upper bound (IQR):
# 905      675000.0
# 13659    675000.0
# 50303    675000.0
# 32035    675000.0
# 51526    675000.0
# Name: Price (€), dtype: float64
#
# percentilessssss
# count         53,992.00
# mean         327,045.86
# std        1,108,128.63
# min            5,260.00
# 50%          252,000.00
# 90%          525,000.00
# 95%          700,000.00
# 99%        1,426,514.62
# 99.5%      2,119,817.59
# max      135,859,819.26
# Name: Price (€), dtype: object
# 1st percentile: 26125.0
# 99th percentile: 1426514.6244999801
# 10      1.426515e+06
# 96      1.426515e+06
# 637     1.426515e+06
# 968     1.426515e+06
# 1458    1.426515e+06
# Name: Price (€), dtype: float64

# %%
sns.histplot(x=df["Price (€)"])
plt.title("Histogram for Outlier Detection")
plt.show()

# %%
# Eircode Handling Strategy

# remove Eircode feature due to high missingness (~69%) and extremely high cardinality
df = df.drop(columns=['Eircode'])

if 'Eircode' not in df.columns:
    print("Eircode successfully removed.")
# Out:
# Eircode successfully removed.

# %%
# Description of Property Handling Strategy

print(df['Description of Property'].value_counts())

# standardise property type categories by translating Irish to English
df.loc[df['Description of Property'] == 'Teach/Árasán Cónaithe Atháimhe', 'Description of Property'] = 'Second-Hand Dwelling house /Apartment'

df['Description of Property'] = df['Description of Property'].cat.remove_unused_categories()

df['Description of Property'].value_counts()
# Out:
# Description of Property
# Second-Hand Dwelling house /Apartment    44359
# New Dwelling house /Apartment             9630
# Teach/Árasán Cónaithe Atháimhe               3
# Name: count, dtype: int64
# Description of Property
# Second-Hand Dwelling house /Apartment    44362
# New Dwelling house /Apartment             9630
# Name: count, dtype: int64

# %%
# Property Size Description Handling Strategy

# remove Property Size Description feature due to extremely high missingness (~95%)
df = df.drop(columns=['Property Size Description'])

if 'Property Size Description' not in df.columns:
    print("Property Size Description successfully removed.")
# Out:
# Property Size Description successfully removed.

# %% [markdown]
# # Renaming Features

# %%
df.columns
# Out:
# Index(['Date of Sale (dd/mm/yyyy)', 'Address', 'County', 'Price (€)',
#        'Not Full Market Price', 'VAT Exclusive', 'Description of Property'],
#       dtype='object')

# %%
df = df.rename(columns={
    'Date of Sale (dd/mm/yyyy)': 'date_of_sale',
    'Address': 'address',
    'County': 'county',
    'Price (€)': 'price',
    'Not Full Market Price': 'not_full_market_price',
    'VAT Exclusive': 'vat_exclusive',
    'Description of Property': 'property_description'
})

df.columns
# Out:
# Index(['date_of_sale', 'address', 'county', 'price', 'not_full_market_price',
#        'vat_exclusive', 'property_description'],
#       dtype='object')

# %%
df.to_csv('../data/ppr-group-25200353-train-clean-final.csv', index=False)

# %%
# Address Handling Strategy

# formatting inconsistencies check
print("Addresses with multiple spaces:", df['Address'].str.contains(r'\s{2,}', regex=True, na=False).sum())
print("Addresses with bad comma spacing:", df['Address'].str.contains(r'\s,|,\S', regex=True, na=False).sum())
print("Addresses with lowercase letters:", df['Address'].str.contains(r'[a-z]', regex=True, na=False).sum())

# counts of abbreviations vs full word
county_count = df['Address'].str.contains(r'\bCOUNTY\b', case=False, regex=True, na=False).sum()
co_count = df['Address'].str.contains(r'\bCO\b', case=False, regex=True, na=False).sum()
print("COUNTY occurrences:", county_count)
print("CO occurrences:", co_count)

street_count = df['Address'].str.contains(r'\bSTREET\b', case=False, regex=True, na=False).sum()
st_count = df['Address'].str.contains(r'\bST\b', case=False, regex=True, na=False).sum()
print("STREET occurrences:", street_count)
print("ST occurrences:", st_count)


road_count = df['Address'].str.contains(r'\bROAD\b', case=False, regex=True, na=False).sum()
rd_count = df['Address'].str.contains(r'\bRD\b', case=False, regex=True, na=False).sum()
print("ROAD occurrences:", road_count)
print("RD occurrences:", rd_count)

avenue_count = df['Address'].str.contains(r'\bAVENUE\b', case=False, regex=True, na=False).sum()
ave_count = df['Address'].str.contains(r'\bAVE\b', case=False, regex=True, na=False).sum()
print("AVENUE occurrences:", avenue_count)
print("AVE occurrences:", ave_count)


before_duplicates = df['Address'].duplicated().sum()

import re

df['Address'] = df['Address'].str.upper()

df['Address'] = df['Address'].str.replace(r'\s+', ' ', regex=True).str.strip()

# standardise abbreviations
df['Address'] = df['Address'].str.replace(r'\bCOUNTY\b', 'CO', regex=True)
df['Address'] = df['Address'].str.replace(r'\bROAD\b', 'RD', regex=True)
df['Address'] = df['Address'].str.replace(r'\bSTREET\b', 'ST', regex=True)
df['Address'] = df['Address'].str.replace(r'\bAVENUE\b', 'AVE', regex=True)    

after_duplicates = df['Address'].duplicated().sum()

# to improve chances of geocoding working, we could add the county to each address string

# if duplicates increase, formatting differences were hiding same addresses
print(after_duplicates - before_duplicates, "duplicate addresses were hidden due to formatting.")
# Out:
# Addresses with multiple spaces: 912
# Addresses with bad comma spacing: 0
# Addresses with lowercase letters: 8461
# COUNTY occurrences: 945
# CO occurrences: 4439
# STREET occurrences: 990
# ST occurrences: 3693
# ROAD occurrences: 4249
# RD occurrences: 7030
# AVENUE occurrences: 1284
# AVE occurrences: 1750
# 69 duplicate addresses were hidden due to formatting.

# %%
# Date of Sale Handling Strategy

# %%
# Confirm feature removal and save to final cleaned file

for column in df.columns:
    print(column)


# Save cleaned data frame to a new CSV file
# df.to_csv('../data/ppr-group-25200353-train-clean-final.csv')
# Out:
# Date of Sale (dd/mm/yyyy)
# Address
# County
# Price (€)
# Not Full Market Price
# VAT Exclusive
# Description of Property

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Exploring relationships between feature pairs.
# - Choose a subset of features you find promising and plot pairwise feature interactions (e.g., continuous-continuous feature plot or continuous-categorical plots or correlation plots). Explain your choices.
# - Discuss your findings from the plots above. Do you find any features or feature combinations that are predictive of the target outcome?
# - Explain in plain words (a short text paragraph) the story of your findings so far.

# %% [markdown]
# ## Price over time

# %%
# Ensure sorted by date
df = df.sort_values('Date of Sale (dd/mm/yyyy)')

try:
    # Set date as index
    df.set_index('Date of Sale (dd/mm/yyyy)', inplace=True)
except:
    pass

monthly_median = df['Price (€)'].resample('ME').median()

plt.figure(figsize=(12,6))
monthly_median.plot()

plt.title('Median Property Price Over Time (Monthly)')
plt.xlabel('Date')
plt.ylabel('Median Price (€)')
plt.grid(True)
plt.show()
